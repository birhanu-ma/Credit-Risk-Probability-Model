# %%
import pandas as pd
import sys, os
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)
from src.data_processing import FeatureEngineering

# %%
df = pd.read_csv("../data/processed/transaction.csv")

# %%
X = df.drop(columns=['FraudResult'])
y = df['FraudResult']

# %%
# Execute Pipeline
fe = FeatureEngineering()
pipeline = fe.build_pipeline()
processed_df = pipeline.fit_transform(X, y)

# %%
print("🎉 Success! Your model-ready data shape is:", processed_df.shape)
processed_df.head()
# Out:
# 🎉 Success! Your model-ready data shape is: (64273, 15)
#    CurrencyCode   CountryCode  ProductCategory  ChannelId    Amount     Value  \
# 0 -5.551115e-17 -5.551115e-17        -0.121582  -0.354644  0.432168  0.265403
# 1 -5.551115e-17 -5.551115e-17        -0.223512   0.184185 -0.662992 -1.002890
# 2 -5.551115e-17 -5.551115e-17        -0.121582  -0.354644 -0.104676 -0.381685
# 3 -5.551115e-17 -5.551115e-17        -0.223512   0.184185 -1.332973 -0.195324
# 4 -5.551115e-17 -5.551115e-17        -0.121582  -0.354644  1.505854  1.559580
#
#    PricingStrategy  Total_Transaction_Amount  Average_Transaction_Amount  \
# 0        -0.298064                 -0.399336                   -0.295118
# 1        -0.298064                 -0.399336                   -0.295118
# 2        -0.298064                 -0.609036                   -0.283507
# 3        -0.298064                 -0.546134                    0.341345
# 4        -0.298064                 -0.604765                    4.078510
#
#    Transaction_Count  Std_Dev_Transaction_Amount  Transaction_Hour  \
# 0          -0.332133                    0.824943         -2.136606
# 1          -0.332133                    0.824943         -2.136606
# 2          -0.558592                   -3.075179         -2.136606
# 3          -0.512843                    0.619439         -1.933964
# 4          -0.560880                   -3.075179         -1.933964
#
#    Transaction_Day  Transaction_Month  Transaction_Year
# 0        -0.192479           0.812629         -0.956226
# 1        -0.192479           0.812629         -0.956226
# 2        -0.192479           0.812629         -0.956226
# 3        -0.192479           0.812629         -0.956226
# 4        -0.192479           0.812629         -0.956226
