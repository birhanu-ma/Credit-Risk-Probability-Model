# %%
import pandas as pd
import sys, os
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)
from src.data_processing import FeatureEngineering

# %%
df = pd.read_csv("../data/processed/transaction.csv")

# %%
X = df.drop(columns=['FraudResult'])
y = df['FraudResult']

# %%
# Execute Pipeline
fe = FeatureEngineering()
pipeline = fe.build_pipeline()
processed_df = pipeline.fit_transform(X, y)

# %%
print("🎉 Success! Your model-ready data shape is:", processed_df.shape)
processed_df.head()
# Out:
# 🎉 Success! Your model-ready data shape is: (64273, 16)
#         CustomerId  CurrencyCode   CountryCode  ProductCategory  ChannelId  \
# 0  CustomerId_4406 -5.551115e-17 -5.551115e-17        -0.121582  -0.354644
# 1  CustomerId_4406 -5.551115e-17 -5.551115e-17        -0.223512   0.184185
# 2  CustomerId_4683 -5.551115e-17 -5.551115e-17        -0.121582  -0.354644
# 3   CustomerId_988 -5.551115e-17 -5.551115e-17        -0.223512   0.184185
# 4  CustomerId_1432 -5.551115e-17 -5.551115e-17        -0.121582  -0.354644
#
#      Amount     Value  PricingStrategy  Total_Transaction_Amount  \
# 0  0.432168  0.265403        -0.298064                 -0.399336
# 1 -0.662992 -1.002890        -0.298064                 -0.399336
# 2 -0.104676 -0.381685        -0.298064                 -0.609036
# 3 -1.332973 -0.195324        -0.298064                 -0.546134
# 4  1.505854  1.559580        -0.298064                 -0.604765
#
# ...

# %%
processed_df.to_csv("../data/processed/processed.csv", index=False)
