# %%
import pandas as pd
import sys, os
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)
from src.model_training import CreditRiskModelTrainer

# %%
df_target = pd.read_csv("../data/processed/final_credit_data.csv")

# %%
df_target.shape
# Out:
# (64273, 18)

# %%
df_processed = pd.read_csv("../data/processed/processed.csv")

# %%
df_processed.shape
# Out:
# (64273, 16)

# %%
print(df_processed['CustomerId'].duplicated().sum())  # should be 0
print(df_target['CustomerId'].duplicated().sum())  # should be 0
# Out:
# 61008
# 61008

# %%
# Load processed features and target
df_processed = pd.read_csv("../data/processed/processed.csv")
df_target = pd.read_csv("../data/processed/final_credit_data.csv")

# -------------------------------
# Keep ONE row per CustomerId
# -------------------------------
df_processed_unique = df_processed.drop_duplicates(subset=["CustomerId"])

df_target_unique = (
    df_target[["CustomerId", "is_high_risk"]]
    .drop_duplicates(subset=["CustomerId"])
)

# -------------------------------
# Merge safely (NO row explosion)
# -------------------------------
train_data = df_processed_unique.merge(
    df_target_unique,
    on="CustomerId",
    how="left"
)

# -------------------------------
# Save train-ready dataset
# -------------------------------
train_data_path = "../data/processed/train_data.csv"
train_data.to_csv(train_data_path, index=False)

print(f"Train-ready dataset saved to: {train_data_path}")
print("Final shape:", train_data.shape)
# Out:
# Train-ready dataset saved to: ../data/processed/train_data.csv
# Final shape: (3265, 17)

# %%
train_dataset = pd.read_csv("../data/processed/train_data.csv")

# %%
print(train_data.is_high_risk.value_counts())
# Out:
# is_high_risk
# 0    2029
# 1    1236
# Name: count, dtype: int64

# %%
train_dataset.shape
# Out:
# (3265, 17)

# %%
train_dataset.head()
# Out:
#         CustomerId  CurrencyCode   CountryCode  ProductCategory  ChannelId  \
# 0  CustomerId_4406 -5.551115e-17 -5.551115e-17        -0.121582  -0.354644
# 1  CustomerId_4683 -5.551115e-17 -5.551115e-17        -0.121582  -0.354644
# 2   CustomerId_988 -5.551115e-17 -5.551115e-17        -0.223512   0.184185
# 3  CustomerId_1432 -5.551115e-17 -5.551115e-17        -0.121582  -0.354644
# 4  CustomerId_2858 -5.551115e-17 -5.551115e-17        -0.223512   0.184185
#
#      Amount     Value  PricingStrategy  Total_Transaction_Amount  \
# 0  0.432168  0.265403        -0.298064                 -0.399336
# 1 -0.104676 -0.381685        -0.298064                 -0.609036
# 2 -1.332973 -0.195324        -0.298064                 -0.546134
# 3  1.505854  1.559580        -0.298064                 -0.604765
# 4 -1.178362 -0.381685        -0.298064                 -0.573586
#
#    Average_Transaction_Amount  Transaction_Count  Std_Dev_Transaction_Amount  \
# 0                   -0.295118          -0.332133                    0.824943
# 1                   -0.283507          -0.558592                   -3.075179
# 2                    0.341345          -0.512843                    0.619439
# 3                    4.078510          -0.560880                   -3.075179
# 4                    0.194238          -0.531142                    1.782344
#
#    Transaction_Hour  Transaction_Day  Transaction_Month  Transaction_Year  \
# 0         -2.136606        -0.192479           0.812629         -0.956226
# 1         -2.136606        -0.192479           0.812629         -0.956226
# 2         -1.933964        -0.192479           0.812629         -0.956226
# 3         -1.933964        -0.192479           0.812629         -0.956226
# 4         -1.933964        -0.192479           0.812629         -0.956226
#
#    is_high_risk
# 0             0
# 1             1
# 2             0
# 3             1
# 4             0

# %%
# Initialize trainer
trainer = CreditRiskModelTrainer(train_dataset)

# Define hyperparameters
lr_params = {'C': [0.01, 0.1, 1, 10], 'solver': ['liblinear']}
rf_params = {'n_estimators': [100, 200], 'max_depth': [5, 10, None]}
gb_params = {'n_estimators': [100, 200], 'learning_rate': [0.01, 0.1], 'max_depth': [3, 5]}

# Train models
trainer.train_model('logistic_regression', params=lr_params)
trainer.train_model('random_forest', params=rf_params)
trainer.train_model('gradient_boosting', params=gb_params)

# Evaluate all models
print(trainer.evaluate_all_models())

# Get best model
best_model = trainer.get_best_model()
# Out:
# 2025/12/16 21:10:38 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/12/16 21:10:38 INFO mlflow.store.db.utils: Updating database tables
# 2025/12/16 21:10:38 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2025/12/16 21:10:38 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2025/12/16 21:10:38 INFO alembic.runtime.migration: Running upgrade  -> 451aebb31d03, add metric step
# 2025/12/16 21:10:38 INFO alembic.runtime.migration: Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# 2025/12/16 21:10:38 INFO alembic.runtime.migration: Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# 2025/12/16 21:10:39 INFO alembic.runtime.migration: Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# 2025/12/16 21:10:39 INFO alembic.runtime.migration: Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# 2025/12/16 21:10:39 INFO alembic.runtime.migration: Running upgrade 7ac759974ad8 -> 89d4b8295536, create latest metrics table
# 2025/12/16 21:10:39 INFO alembic.runtime.migration: Running upgrade 89d4b8295536 -> 2b4d017a5e9b, add model registry tables to db
# 2025/12/16 21:10:39 INFO alembic.runtime.migration: Running upgrade 2b4d017a5e9b -> cfd24bdc0731, Update run status constraint with killed
# 2025/12/16 21:10:39 INFO alembic.runtime.migration: Running upgrade cfd24bdc0731 -> 0a8213491aaa, drop_duplicate_killed_constraint
# 2025/12/16 21:10:39 INFO alembic.runtime.migration: Running upgrade 0a8213491aaa -> 728d730b5ebd, add registered model tags table
# 2025/12/16 21:10:39 INFO alembic.runtime.migration: Running upgrade 728d730b5ebd -> 27a6a02d2cf1, add model version tags table
# 2025/12/16 21:10:39 INFO alembic.runtime.migration: Running upgrade 27a6a02d2cf1 -> 84291f40a231, add run_link to model_version
# 2025/12/16 21:10:39 INFO alembic.runtime.migration: Running upgrade 84291f40a231 -> a8c4a736bde6, allow nulls for run_id
# 2025/12/16 21:10:39 INFO alembic.runtime.migration: Running upgrade a8c4a736bde6 -> 39d1c3be5f05, add_is_nan_constraint_for_metrics_tables_if_necessary
# 2025/12/16 21:10:39 INFO alembic.runtime.migration: Running upgrade 39d1c3be5f05 -> c48cb773bb87, reset_default_value_for_is_nan_in_metrics_table_for_mysql
# 2025/12/16 21:10:39 INFO alembic.runtime.migration: Running upgrade c48cb773bb87 -> bd07f7e963c5, create index on run_uuid
# 2025/12/16 21:10:39 INFO alembic.runtime.migration: Running upgrade bd07f7e963c5 -> 0c779009ac13, add deleted_time field to runs table
# 2025/12/16 21:10:40 INFO alembic.runtime.migration: Running upgrade 0c779009ac13 -> cc1f77228345, change param value length to 500
# 2025/12/16 21:10:40 INFO alembic.runtime.migration: Running upgrade cc1f77228345 -> 97727af70f4d, Add creation_time and last_update_time to experiments table
# 2025/12/16 21:10:40 INFO alembic.runtime.migration: Running upgrade 97727af70f4d -> 3500859a5d39, Add Model Aliases table
# 2025/12/16 21:10:40 INFO alembic.runtime.migration: Running upgrade 3500859a5d39 -> 7f2a7d5fae7d, add datasets inputs input_tags tables
# 2025/12/16 21:10:40 INFO alembic.runtime.migration: Running upgrade 7f2a7d5fae7d -> 2d6e25af4d3e, increase max param val length from 500 to 8000
# 2025/12/16 21:10:40 INFO alembic.runtime.migration: Running upgrade 2d6e25af4d3e -> acf3f17fdcc7, add storage location field to model versions
# 2025/12/16 21:10:40 INFO alembic.runtime.migration: Running upgrade acf3f17fdcc7 -> 867495a8f9d4, add trace tables
# 2025/12/16 21:10:40 INFO alembic.runtime.migration: Running upgrade 867495a8f9d4 -> 5b0e9adcef9c, add cascade deletion to trace tables foreign keys
# 2025/12/16 21:10:40 INFO alembic.runtime.migration: Running upgrade 5b0e9adcef9c -> 4465047574b1, increase max dataset schema size
# 2025/12/16 21:10:40 INFO alembic.runtime.migration: Running upgrade 4465047574b1 -> f5a4f2784254, increase run tag value limit to 8000
# 2025/12/16 21:10:40 INFO alembic.runtime.migration: Running upgrade f5a4f2784254 -> 0584bdc529eb, add cascading deletion to datasets from experiments
# 2025/12/16 21:10:40 INFO alembic.runtime.migration: Running upgrade 0584bdc529eb -> 400f98739977, add logged model tables
# 2025/12/16 21:10:41 INFO alembic.runtime.migration: Running upgrade 400f98739977 -> 6953534de441, add step to inputs table
# 2025/12/16 21:10:41 INFO alembic.runtime.migration: Running upgrade 6953534de441 -> bda7b8c39065, increase_model_version_tag_value_limit
# 2025/12/16 21:10:41 INFO alembic.runtime.migration: Running upgrade bda7b8c39065 -> cbc13b556ace, add V3 trace schema columns
# 2025/12/16 21:10:41 INFO alembic.runtime.migration: Running upgrade cbc13b556ace -> 770bee3ae1dd, add assessments table
# 2025/12/16 21:10:41 INFO alembic.runtime.migration: Running upgrade 770bee3ae1dd -> a1b2c3d4e5f6, add spans table
# 2025/12/16 21:10:41 INFO alembic.runtime.migration: Running upgrade a1b2c3d4e5f6 -> de4033877273, create entity_associations table
# 2025/12/16 21:10:41 INFO alembic.runtime.migration: Running upgrade de4033877273 -> 1a0cddfcaa16, Add webhooks and webhook_events tables
# 2025/12/16 21:10:41 INFO alembic.runtime.migration: Running upgrade 1a0cddfcaa16 -> 534353b11cbc, add scorer tables
# 2025/12/16 21:10:41 INFO alembic.runtime.migration: Running upgrade 534353b11cbc -> 71994744cf8e, add evaluation datasets
# 2025/12/16 21:10:41 INFO alembic.runtime.migration: Running upgrade 71994744cf8e -> 3da73c924c2f, add outputs to dataset record
# 2025/12/16 21:10:42 INFO alembic.runtime.migration: Running upgrade 3da73c924c2f -> bf29a5ff90ea, add jobs table
# 2025/12/16 21:10:42 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2025/12/16 21:10:42 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2025/12/16 21:10:42 INFO mlflow.tracking.fluent: Experiment with name 'Credit_Risk_Model' does not exist. Creating a new experiment.
# 2025/12/16 21:10:43 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# logistic_regression trained. ROC-AUC: 0.9309
# 2025/12/16 21:11:07 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# random_forest trained. ROC-AUC: 0.9709
# 2025/12/16 21:11:28 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# gradient_boosting trained. ROC-AUC: 0.9669
#                      accuracy  precision    recall  f1_score   roc_auc
# logistic_regression  0.863706   0.821138  0.817814  0.819473  0.930895
# random_forest        0.891271   0.879310  0.825911  0.851775  0.970902
# gradient_boosting    0.888208   0.868644  0.829960  0.848861  0.966943
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 21
#      18 best_model = trainer.get_best_model()
#      20 # Predict on new customer data
# ---> 21 new_customers = pd.read_csv("data/processed/new_customers.csv")
#      22 predictions = trainer.predict(new_customers)
#      23 print(predictions.head())
#
# File c:\Users\Birhanu Matebe\Downloads\KAIM\Credit-Risk\Credit-Risk-Probability-Model\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Birhanu Matebe\Downloads\KAIM\Credit-Risk\Credit-Risk-Probability-Model\.venv\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\Birhanu Matebe\Downloads\KAIM\Credit-Risk\Credit-Risk-Probability-Model\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Birhanu Matebe\Downloads\KAIM\Credit-Risk\Credit-Risk-Probability-Model\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\Birhanu Matebe\Downloads\KAIM\Credit-Risk\Credit-Risk-Probability-Model\.venv\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/processed/new_customers.csv'
